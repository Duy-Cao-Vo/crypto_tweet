# %%
import os
os.environ['HDF5_DISABLE_VERSION_CHECK']='2'
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
import tensorflow as tf
import keras
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\Admin\anaconda3\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.4, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# Num GPUs Available:  1
# Using TensorFlow backend.

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import numpy as np
import glob
df_t = pd.DataFrame()
for i in glob.glob('./data/bitcoin_*'):
    df_i = pd.read_excel(i)
    df_t = pd.concat([df_t, df_i])

# %%
pd.options.display.max_colwidth = 200
pd.options.display.max_columns = 100

# %%
df_t.info()

# %%
df_t

# %%
# drop duplicates
df_t = df_t.sort_values(['conversationId','date'], ascending=[True, False])
df_t['_id'] = df_t.groupby('conversationId')['date'].cumcount()+1

# %%
df_t = df_t[df_t['_id']==1]

# %%
import re
def extract_followers_count(text):
    followers_count_match = re.search(r'followersCount=(\d+)', text)

    if followers_count_match:
        followers_count = int(followers_count_match.group(1))
        return followers_count
    else:
        return 0

# %%
df_t['followersCount'] = df_t['user'].apply(extract_followers_count)

# %%
df_t

# %%
df_t['user'].iloc[0]

# %%
x = df_t.groupby('d')['conversationId'].count().reset_index()
x = x.sort_values('d')

# %%
import plotly.express as px
fig = px.bar(x, x='d', y='conversationId')
fig.show()

# %%
df_a = df_t.groupby('d')[['conversationId','viewCount','replyCount','retweetCount','followersCount','likeCount']].agg(
    {"conversationId": 'nunique', 
     "viewCount": np.sum,
    "replyCount": np.sum,
    "retweetCount": np.sum,
     "followersCount": np.sum,
    "likeCount": np.sum}).reset_index()

# %%
df_a

# %%
import pandas as pd
import numpy as np

df_b = pd.read_excel("./data/btc_price.xlsx")

# %%
df_b

# %%
df_b['d'] = pd.to_datetime(df_b['Timestamp']).dt.date

# %%
df_a['d'] = pd.to_datetime(df_a['d'])
df_b['d'] = pd.to_datetime(df_b['d'])

# %%
df_b.info()

# %%
df = pd.merge(df_a, df_b[['d','High']], on = 'd', how='left')
df = df[df['d']>='2017-08-17']

# %%
df

# %%
import plotly.express as px
fig = px.bar(df, x='d', y='High')
fig.show()

# %%
import plotly.express as px
fig = px.bar(df, x='d', y='replyCount')
fig.show()

# %% [markdown]
# # Model

# %%
df = df.sort_values('d')
df = df.set_index('d')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(df.values)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    '''
    Converts the original dataframe to a format which contains
    lag shifted values of inputs which can be used as input
    to the LSTM
    '''
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
n_days = 7  #no of time lags
n_features = 6 #no of features
n_obs = n_days*n_features

# %%
n_obs
# Out:
# 42

# %%
reframed = series_to_supervised(scaled, n_days, 1, 1)
reframed
# Out:
#       var1(t-7)  var2(t-7)  var3(t-7)  var4(t-7)  var5(t-7)  var6(t-7)  \
# 7      0.680556   0.000000   0.000034   0.000195   0.021780   0.000048
# 8      0.736111   0.000000   0.000039   0.000094   0.005175   0.000065
# 9      0.722222   0.000000   0.000073   0.001062   0.027689   0.000895
# 10     0.833333   0.000000   0.000058   0.000417   0.025471   0.000178
# 11     0.861111   0.000000   0.000112   0.000375   0.054914   0.000289
# ...         ...        ...        ...        ...        ...        ...
t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)   var6(t)  \
# 7      0.020860  0.000000  0.000000  0.000034  0.000495  0.000211  0.000227
# 8      0.022350  0.736111  0.000000  0.000068  0.000312  0.002160  0.000098
# 9      0.024482  0.750000  0.000000  0.000395  0.002218  0.020525  0.001848
# 10     0.021883  0.888889  0.000000  0.000029  0.000109  0.006816  0.000034
# 11     0.018387  0.875000  0.000000  0.000244  0.021302  0.006801  0.006593
# ...         ...       ...       ...       ...       ...       ...       ...
# 1547   0.626931  0.777778  0.000038  0.000312  0.000120  0.014675  0.000247
# 1548   0.680054  0.013889  0.000021  0.000015  0.000086  0.000030  0.000008
# 1549   0.675853  0.847222  0.002250  0.007570  0.009521  0.023840  0.013281
# 1550   0.695230  0.000000  0.004523  0.013567  0.004545  0.011678  0.007058
# 1551   0.657893  0.819444  0.000089  0.000424  0.000236  0.010621  0.000459
#
#        var7(t)
# 7     0.022350
# 8     0.024482
# 9     0.021883
# 10    0.018387
# 11    0.023007
# ...        ...
# 1547  0.680054
# 1548  0.675853
# 1549  0.695230
# 1550  0.657893
# 1551  0.608283
#
# [1545 rows x 56 columns]

# %%
values = reframed.values
n_train_days = round(len(df)*0.7)
train = values[:n_train_days, :]
test = values[n_train_days:, :]
train.shape
# Out:
# (1086, 56)

# %%
# split into input and outputs
train_X, train_y = train[:, :(n_features+1)*n_days], train[:, -1]
test_X, test_y = test[:, :(n_features+1)*n_days], test[:, -1]

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features+1))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features+1))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1086, 7, 7) (1086,) (459, 7, 7) (459,)

# %%
reframed[:n_train_days]
# Out:
#       var1(t-7)  var2(t-7)  var3(t-7)  var4(t-7)  var5(t-7)  var6(t-7)  \
# 7      0.680556        0.0   0.000034   0.000195   0.021780   0.000048
# 8      0.736111        0.0   0.000039   0.000094   0.005175   0.000065
# 9      0.722222        0.0   0.000073   0.001062   0.027689   0.000895
# 10     0.833333        0.0   0.000058   0.000417   0.025471   0.000178
# 11     0.861111        0.0   0.000112   0.000375   0.054914   0.000289
# ...         ...        ...        ...        ...        ...        ...
# 1088   0.888889        0.0   0.125163   0.076059   0.042479   0.032842
# 1089   0.000000        0.0   0.007483   0.008767   0.001864   0.005206
# 1090   0.722222        0.0   0.003327   0.006894   0.030857   0.017891
# 1091   0.722222        0.0   0.006041   0.017410   0.027472   0.021494
# 1092   0.750000        0.0   0.001515   0.007949   0.003724   0.008424
#
#       var7(t-7)  var1(t-6)  var2(t-6)  var3(t-6)  var4(t-6)  var5(t-6)  \
# 7      0.016661   0.736111        0.0   0.000039   0.000094   0.005175
# 8      0.014220   0.722222        0.0   0.000073   0.001062   0.027689
# 9      0.012603   0.833333        0.0   0.000058   0.000417   0.025471
# 10     0.016663   0.861111        0.0   0.000112   0.000375   0.054914
# 11     0.016592   0.722222        0.0   0.000093   0.000323   0.021998
# ...         ...        ...        ...        ...        ...        ...
# 1088   0.600752   0.000000        0.0   0.007483   0.008767   0.001864
# 1089   0.602005   0.722222        0.0   0.003327   0.006894   0.030857
# 1090   0.631051   0.722222        0.0   0.006041   0.017410   0.027472
# 1091   0.622125   0.750000        0.0   0.001515   0.007949   0.003724
# 1092   0.565518   0.000000        0.0   0.000005   0.000000   0.000002
#
#       var6(t-6)  var7(t-6)  var1(t-5)  var2(t-5)  var3(t-5)
t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)   var6(t)  \
# 1093   0.556562  0.736111  0.000000  0.003926  0.005153  0.026065  0.006795
# 1094   0.634058  0.013889  0.000000  0.001135  0.005701  0.001246  0.004008
# 1095   0.640920  0.791667  0.000000  0.004267  0.008688  0.002968  0.010863
# 1096   0.621157  0.722222  0.000000  0.001213  0.004751  0.091146  0.003978
# 1097   0.552873  0.763889  0.000000  0.005782  0.002894  0.027608  0.006991
# ...         ...       ...       ...       ...       ...       ...       ...
# 1540   0.616611  0.819444  0.000656  0.001617  0.003678  0.002937  0.004905
# 1541   0.613421  0.569444  0.001403  0.001890  0.001648  0.003341  0.003063
# 1542   0.616386  0.847222  0.012559  0.029068  0.001895  0.002630  0.006532
# 1543   0.598505  0.833333  0.006526  0.003956  0.008827  0.022369  0.028448
# 1544   0.622420  0.750000  0.076905  0.033370  0.077590  0.024161  0.210618
#
#        var7(t)
# 1093  0.634058
# 1094  0.640920
# 1095  0.621157
# 1096  0.552873
# 1097  0.551874
# ...        ...
# 1540  0.613421
# 1541  0.616386
# 1542  0.598505
# 1543  0.622420
# 1544  0.642441
#
# [452 rows x 56 columns]

# %%
pd.DataFrame(test[:, -1])
# Out:
#             0
# 0    0.634058
# 1    0.640920
# 2    0.621157
# 3    0.552873
# 4    0.551874
# ..        ...
# 454  0.680054
# 455  0.675853
# 456  0.695230
# 457  0.657893
# 458  0.608283
#
# [459 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
# from keras.layers import Dense
# from keras.layers import LSTM
from tensorflow.keras.layers import LSTM, Dense
# from elephas.utils.rdd_utils import to_simple_rdd
# design network
model = Sequential()
model.add(LSTM(8, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(4, activation='relu'))
model.add(Dense(1))
model.compile(loss='mse', metrics=['mae', 'mse'],optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))
# fit network

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, patience=300, verbose=0, mode='auto', baseline=None, restore_best_weights=True)
history = model.fit(train_X, train_y, epochs=1000, batch_size=4, validation_data=(test_X, test_y), callbacks=[callback])
# plot history|
# Out:
# Epoch 1/1000
# 272/272 [==============================] - 5s 13ms/step - loss: 0.0759 - mae: 0.1678 - mse: 0.0759 - val_loss: 0.0079 - val_mae: 0.0635 - val_mse: 0.0079
# Epoch 2/1000
# 272/272 [==============================] - 2s 9ms/step - loss: 0.0088 - mae: 0.0609 - mse: 0.0088 - val_loss: 0.0041 - val_mae: 0.0422 - val_mse: 0.0041
# Epoch 3/1000
# 265/272 [============================>.] - ETA: 0s - loss: 0.0044 - mae: 0.0417 - mse: 0.0044

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling
from keras.callbacks import EarlyStopping

# %%
import chart_studio as py
import plotly.offline as pyoff
import plotly.graph_objs as go
import matplotlib.pyplot as plt

# %%
hist = pd.DataFrame(history.history)
a=hist.val_loss.min()
b=hist[hist.val_loss==a].reset_index()
c=b['index'].iloc[0]
print('Epochs min val_mae:')
print(hist[hist.val_loss==a].reset_index())
# print(hist[hist.val_loss==a].reset_index().iloc[0,0], hist[hist.val_loss==a].iloc[0]['loss'])
plotter = tfdocs.plots.HistoryPlotter()#smoothing_std=0.01)
plotter.plot({'Basic': history}, metric = "mae")
# plt.ylim([a-a, a+a])
# plt.xlim([c-c/2, c+c])
plt.ylabel('MAE [MPG]')

# %%
yhat = model.predict(test_X)
yhat = yhat[:,0]
yhat = yhat.reshape((test_X.shape[0], 1))

# %%
pd.DataFrame(scaler.inverse_transform(scaled[len(train_X):-n_days])).head(n_days+1)

# %%
Test_X = test_X.reshape((test_X.shape[0], n_days* (n_features+1)))
inv_yhat = np.concatenate((Test_X[:, :n_features], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)

# %%
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((Test_X[:, :n_features], test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)

# %%
pd.DataFrame(inv_y)

# %%
pd.DataFrame(inv_yhat)

# %%
# inv_yhat = inv_yhat[:,-1]
# inv_y = inv_y[:,-1]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse = np.sqrt(mean_squared_error(inv_y[:,-1], inv_yhat[:,-1]))
print('Test RMSE: %.3f' % rmse)
rmse/df.iloc[n_train_days:]['High'].mean()

# %%
mae = mean_absolute_error(inv_y[:,-1], inv_yhat[:,-1])
print('Test MAE: %.3f' % mae)
mae/df.iloc[n_train_days:]['High'].mean()

# %%
mae = mean_absolute_error(inv_y[:,-1][:30], inv_yhat[:,-1][:30])
print('Test MAE: %.3f' % mae)
mae/df.iloc[n_train_days:]['High'].mean()

# %%
df_y = pd.DataFrame(inv_y)
df_y.index = df.iloc[n_train_days:-n_days].index
df_y.columns = df.columns
df_y['color'] = 'test'

# %%
df_yhat = pd.DataFrame(inv_yhat)
df_yhat.index = df.iloc[n_train_days:-n_days].index
df_yhat.columns = df.columns
df_yhat['color'] = 'predict'

# %%
df_draw = pd.concat([df_y, df_yhat]).reset_index()

# %%
import plotly.express as px
fig = px.line(df_draw, x='d', y='High', color='color')
fig.show()
# Out:
# <div>                            <div id="3a4d1e73-4a5c-4a78-967e-c2bb1b71e73f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a4d1e73-4a5c-4a78-967e-c2bb1b71e73f")) {                    Plotly.newPlot(                        "3a4d1e73-4a5c-4a78-967e-c2bb1b71e73f",                        [{"hovertemplate":"color=test<br>d=%{x}<br>High=%{y}<extra></extra>","legendgroup":"test","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"test","orientation":"v","showlegend":true,"x":["2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-05T00:00:00","2022-03-07T00:00:00","2022-03-09T00:00:00","2022-03-11T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-19T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-25T00:00:00","2022-03-27T00:00:00","2022-03-29T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-04T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-10T00:00:00","2022-04-12T00:00:00","2022-04-14T00:00:00","2022-04-16T00:00:00","2022-04-18T00:00:00","2022-04-20T00:00:00","2022-04-22T00:00:00","2022-04-24T00:00:00","2022-04-26T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-30T00:00:00","2022-05-02T00:00:00","2022-05-04T00:00:00","2022-05-06T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-14T00:00:00","2022-05-16T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-22T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-26T00:00:00","2022-05-28T00:00:00","2022-05-30T00:00:00","2022-05-31T00:00:00","2022-06-01T00:00:00","2022-06-03T00:00:00","2022-06-05T00:00:00","2022-06-07T00:00:00","2022-06-09T00:00:00","2022-06-11T00:00:00","2022-06-13T00:00:00","2022-06-15T00:00:00","2022-06-17T00:00:00","2022-06-18T00:00:00","2022-06-19T00:00:00","2022-06-21T00:00:00","2022-06-22T00:00:00","2022-06-23T00:00:00","2022-06-25T00:00:00","2022-06-27T00:00:00","2022-06-29T00:00:00","2022-07-01T00:00:00","2022-07-03T00:00:00","2022-07-04T00:00:00","2022-07-05T00:00:00","2022-07-06T00:00:00","2022-07-07T00:00:00","2022-07-08T00:00:00","2022-07-09T00:00:00","2022-07-10T00:00:00","2022-07-11T00:00:00","2022-07-13T00:00:00","2022-07-15T00:00:00","2022-07-16T00:00:00","2022-07-17T00:00:00","2022-07-18T00:00:00","2022-07-19T00:00:00","2022-07-20T00:00:00","2022-07-21T00:00:00","2022-07-22T00:00:00","2022-07-23T00:00:00","2022-07-25T00:00:00","2022-07-26T00:00:00","2022-07-27T00:00:00","2022-07-29T00:00:00","2022-07-30T00:00:00","2022-07-31T00:00:00","2022-08-02T00:00:00","2022-08-03T00:00:00","2022-08-04T00:00:00","2022-08-06T00:00:00","2022-08-07T00:00:00","2022-08-08T00:00:00","2022-08-10T00:00:00","2022-08-12T00:00:00","2022-08-14T00:00:00","2022-08-15T00:00:00","2022-08-16T00:00:00","2022-08-18T00:00:00","2022-08-20T00:00:00","2022-08-22T00:00:00","2022-08-24T00:00:00","2022-08-26T00:00:00","2022-08-27T00:00:00","2022-08-28T00:00:00","2022-08-30T00:00:00","2022-09-01T00:00:00","2022-09-02T00:00:00","2022-09-03T00:00:00","2022-09-05T00:00:00","2022-09-07T00:00:00","2022-09-09T00:00:00","2022-09-11T00:00:00","2022-09-12T00:00:00","2022-09-13T00:00:00","2022-09-15T00:00:00","2022-09-17T00:00:00","2022-09-19T00:00:00","2022-09-20T00:00:00","2022-09-21T00:00:00","2022-09-22T00:00:00","2022-09-23T00:00:00","2022-09-24T00:00:00","2022-09-25T00:00:00","2022-09-27T00:00:00","2022-09-28T00:00:00","2022 ...

# %%
model.save('2024-01-21.keras')

# %%
new_model = tf.keras.models.load_model('2024-01-21.keras')

# %%
new_model.summary()
